# %% [markdown]
# # Training my first Deep Reinforcement Learning Agent 🤖
#
# In this notebook, I'll train my **first Deep Reinforcement Learning agent** a Lunar Lander agent that will learn to **land correctly on the Moon 🌕**. I'm using [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) a Deep Reinforcement Learning library.

# %% [markdown]
# ### The environment 🎮
# - [LunarLander-v2](https://www.gymlibrary.dev/environments/box2d/lunar_lander/)
#
# ### The library used 📚
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/)

# %% [markdown]
# ## Install dependencies and create a virtual screen 🔽
# The first step is to install the dependencies, we’ll install multiple ones.
#
# - `gym[box2D]`: Contains the LunarLander-v2 environment 🌛 (we use `gym==0.21`)
# - `stable-baselines3[extra]`: The deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 23 not upgraded.
# Need to get 1,086 kB of archives.
# After this operation, 5,413 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Fetched 1,086 kB in 1s (2,124 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 128276 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up swig (4.0.1-5build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 KB 5.3 MB/s eta 0:00:00
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 KB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface_sb3
#   Downloading huggingface_sb3-2.2.4-py3-none-any.whl (9.4 kB)
# Collecting pyglet==1.5.1
#   Downloading pyglet-1.5.1-py2.py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.13.1+cu116)
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.22.4)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 84.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.2.1)
# Collecting rich
#   Downloading rich-13.3.2-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (8.4.0)
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.65.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (5.9.4)
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.9/dist-packages (from ale-py==0.7.4->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (5.12.0)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.9/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (6.0)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.9/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (1.1.1)
# Collecting huggingface-hub~=0.8
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.27.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.0.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 KB 47.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata~=4.13->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.15.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.51.3)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.19.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.16.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.40.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (63.4.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.2.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2022.7.1)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 80.3 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.3.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.1.2)
# Collecting libtorrent
#   Downloading libtorrent-2.0.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 113.4 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.2.2)
# Building wheels for collected packages: gym, box2d-py, AutoROM.accept-rom-license
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for gym (setup.py) ... error
#   ERROR: Failed building wheel for gym
#   Running setup.py clean for gym
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp39-cp39-linux_x86_64.whl size=2778416 sha256=8fcf9d309b399067167ebc5d54a04464fded5269bd8257f28c934441f8869c06
#   Stored in directory: /root/.cache/pip/wheels/a0/6a/54/2383a12859109612796c6b235ff6704a82b99caa4308ca0b43
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.0-py3-none-any.whl size=446686 sha256=04809fcb87b5e9edb2c7e3d26d998b13421b78766b985d7314493aafebcc8cb7
#   Stored in directory: /root/.cache/pip/wheels/7d/17/c9/c31922a6aaf4ec7ec90eeee5dbc40ffbaafeda64b30a208b72
# Successfully built box2d-py AutoROM.accept-rom-license
# Failed to build gym
# Installing collected packages: pyglet, libtorrent, box2d-py, pygments, mdurl, importlib-metadata, gym, markdown-it-py, huggingface-hub, AutoROM.accept-rom-license, autorom, ale-py, stable-baselines3, rich, huggingface_sb3
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Running setup.py install for gym ... done
#   DEPRECATION: gym was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed AutoROM.accept-rom-license-0.6.0 ale-py-0.7.4 autorom-0.4.2 box2d-py-2.3.8 gym-0.21.0 huggingface-hub-0.13.3 huggingface_sb3-2.2.4 importlib-metadata-4.13.0 libtorrent-2.0.7 markdown-it-py-2.2.0 mdurl-0.1.2 pyglet-1.5.1 pygments-2.14.0 rich-13.3.2 stable-baselines3-1.7.0

# %%
# !sudo apt-get update
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [923 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [74.2 kB]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,545 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,019 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,314 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,026 kB]
# Hit:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,141 kB]
# Hit:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:18 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,403 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,138 kB]
# Fetched 14.9 MB in 3s (4,545 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libpython2-stdlib python2 python2-minimal
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc
# The following NEW packages will be installed:
#   freeglut3 libpython2-stdlib python-opengl python2 python2-minimal
# 0 upgraded, 5 newly installed, 0 to remove and 41 not upgraded.
# Need to get 621 kB of archives.
# After this operation, 6,059 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Fetched 621 kB in 0s (2,175 kB/s)
# Selecting previously unselected package python2-minimal.
# (Reading database ... 129027 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 129056 files and directories currently installed.)
# Preparing to unpack .../python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../python-opengl_3.1.0+dfsg-2build1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up python-opengl (3.1.0+dfsg-2build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 780 kB of archives.
# After this operation, 2,271 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.6 [780 kB]
# Fetched 780 kB in 0s (2,308 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 131444 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.20.13-1ubuntu1~20.04.6_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.6) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.6) ...
# Processing triggers for man-db (2.9.1-1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Import the packages 📦
#
# One additional library we import is huggingface_hub **to be able to upload and download trained models from the hub**.
#
# You can see here all the Deep reinforcement Learning models available 👉 https://huggingface.co/models?pipeline_tag=reinforcement-learning&sort=downloads

# %%
import gym

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ## Understand what is LunarLander Environment and How it works 🚀
# ###Action Space
# There are four discrete actions available: do nothing, fire left orientation engine, fire main engine, fire right orientation engine.
# - Do nothing,
# - Fire left orientation engine,
# - Fire the main engine,
# - Fire right orientation engine.
#
# ###Observation Space
# The state is an 8-dimensional vector: the coordinates of the lander in x & y, its linear velocities in x & y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.
# - Horizontal pad coordinate (x)
# - Vertical pad coordinate (y)
# - Horizontal speed (x)
# - Vertical speed (y)
# - Angle
# - Angular speed
# - If the left leg has contact point touched the land
# - If the right leg has contact point touched the land
#
# ###Rewards
# - Moving from the top of the screen to the landing pad and zero speed is about 100~140 points.
# - Firing main engine is -0.3 each frame
# - Each leg ground contact is +10 points
# - Episode finishes if the lander crashes (additional - 100 points) or come to rest (+100 points)

# %%
# create the environment
env = gym.make("LunarLander-v2")

# reset the environment to initial state
observation = env.reset()

for _ in range(10):
  print("---------------------------")

  # take a random action
  action = env.action_space.sample()
  print("Action taken: ", action)

  observation, reward, done, info = env.step(action)
  print("Observation: ", observation)
  print("Reward: ", reward)

  # If the game is done (in our case we land, crashed or timeout)
  if done:
    # Reset the environment
    print("Environment is reset")
    observation = env.reset()
# Out:
# ---------------------------
# Action taken:  3
# Observation:  [-0.01515503  1.4153616  -0.7601681   0.08560633  0.01535855  0.1304709
#   0.          0.        ]
# Reward:  0.6025386020033647
# ---------------------------
# Action taken:  2
# Observation:  [-0.0227375   1.417569   -0.76466954  0.09802797  0.02169633  0.12676743
#   0.          0.        ]
# Reward:  -1.7600620968701322
# ---------------------------
# Action taken:  2
# Observation:  [-0.03032856  1.4197516  -0.76551473  0.09689875  0.02803298  0.12674493
#   0.          0.        ]
# Reward:  -1.2356458812990525
# ---------------------------
# Action taken:  2
# Observation:  [-0.03810682  1.4228346  -0.78344953  0.13690223  0.03360759  0.11150227
#   0.          0.        ]
# Reward:  -3.554176033630415
# ---------------------------
# Action taken:  2
# Observation:  [-0.04606523  1.4261175  -0.80069077  0.1457906   0.03840673  0.09599131
#   0.          0.        ]
# Reward:  -2.985006956070708
# ---------------------------
# Action taken:  0
# Observation:  [-0.05402384  1.4288007  -0.80070484  0.1191199   0.04320544  0.09598278
#   0.          0.        ]
# Reward:  -0.3420767665066933
# ---------------------------
# Action taken:  1
# Observation:  [-0.06207895  1.4308704  -0.8128297   0.09175714  0.05044052  0.14471486
#   0.          0.        ]
# Reward:  -1.8405104428780692
# ---------------------------
# Action taken:  0
# Observation:  [-0.07013445  1.4323406  -0.81285274  0.06508466  0.05767338  0.14467083
#   0.          0.        ]
# Reward:  -0.6535060631628653
# ---------------------------
# Action taken:  2
# Observation:  [-0.0781312   1.4347749  -0.80754966  0.10786343  0.06546933  0.155933
#   0.          0.        ]
# Reward:  -1.290699683921548
# ---------------------------
# Action taken:  1
# Observation:  [-0.08618908  1.4366133  -0.81518257  0.08126935  0.07478361  0.18630286
#   0.          0.        ]
# Reward:  -1.6412349594530997

# %% [markdown]
# ### Vectorized Environment
# - We create a vectorized environment (method for stacking multiple independent environments into a single environment) of 16 environments, this way, **we'll have more diverse experiences during the training.**

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Create the Model 🤖
# - Now that we studied our environment and we understood the problem: **being able to land correctly the Lunar Lander to the Landing Pad by controlling left, right and main orientation engine**. Let's build the algorithm we're going to use to solve this Problem 🚀.
#
# - To do so, we're going to use our first Deep RL library, [Stable Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/).
#
# - SB3 is a set of **reliable implementations of reinforcement learning algorithms in PyTorch**.
#
# ---
#
# 💡 A good habit when using a new library is to dive first on the documentation: https://stable-baselines3.readthedocs.io/en/master/ and then try some tutorials.
#
# ----

# %% [markdown]
# To solve this problem, we're going to use SB3 **PPO**. [PPO (aka Proximal Policy Optimization) is one of the of the SOTA (state of the art) Deep Reinforcement Learning algorithms.
#
# PPO is a combination of:
# - *Value-based reinforcement learning method*: learning an action-value function that will tell us what's the **most valuable action to take given a state and action**.
# - *Policy-based reinforcement learning method*: learning a policy that will **gives us a probability distribution over actions**.

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 32,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cpu device

# %%
# Train it for 1,500,000 timesteps
model.learn(total_timesteps=1500000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.7     |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    fps             | 4597     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 94.8      |
# |    ep_rew_mean          | -158      |
# | time/                   |           |
# |    fps                  | 2468      |
# |    iterations           | 2         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.009522  |
# |    clip_fraction        | 0.072     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.38     |
# |    explained_variance   | -0.000881 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.19e+03  |
# |    n_updates            | 4         |
# |    policy_gradient_loss | -0.00646  |
# |    value_loss           | 3.87e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.1        |
# |    ep_rew_mean          | -134        |
# | time/                   |             |
# |    fps                  | 2212        |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007839154 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00421     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 586         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 2.01e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.5         |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 2106         |
# |    iterations           | 4            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0064423033 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0285      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 800          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 2002        |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008130274 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -2.59e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 179         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 689         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.5         |
# |    ep_rew_mean          | -87          |
# | time/                   |              |
# |    fps                  | 1967         |
# |    iterations           | 6            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0065011145 |
# |    clip_fraction        | 0.0739       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.000682    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 879          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 930          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -65.5       |
# | time/                   |             |
# |    fps                  | 1939        |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008221053 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.152      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 418         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -51.8       |
# | time/                   |             |
# |    fps                  | 1902        |
# |    iterations           | 8           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008370083 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -8.46e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 413         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | -28.2       |
# | time/                   |             |
# |    fps                  | 1868        |
# |    iterations           | 9           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.009360932 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.00566    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 292         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 447         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | -27.7        |
# | time/                   |              |
# |    fps                  | 1783         |
# |    iterations           | 10           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0054018716 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 256          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 445          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 11          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008231808 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 667         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | -3.93       |
# | time/                   |             |
# |    fps                  | 1573        |
# |    iterations           | 12          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011816248 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -1.67e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 267         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 611         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | 2.48       |
# | time/                   |            |
# |    fps                  | 1452       |
# |    iterations           | 13         |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.00846481 |
# |    clip_fraction        | 0.08       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 261        |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.000864  |
# |    value_loss           | 461        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 394          |
# |    ep_rew_mean          | 6.61         |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 14           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0071945786 |
# |    clip_fraction        | 0.0913       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89           |
# |    n_updates            | 52           |
# |    policy_gradient_loss | 0.000301     |
# |    value_loss           | 413          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 472        |
# |    ep_rew_mean          | 7.8        |
# | time/                   |            |
# |    fps                  | 1279       |
# |    iterations           | 15         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.00927624 |
# |    clip_fraction        | 0.0826     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 2.38e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 200        |
# |    n_updates            | 56         |
# |    policy_gradient_loss | -0.00197   |
# |    value_loss           | 411        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 521         |
# |    ep_rew_mean          | 9.71        |
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 16          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.009260677 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 4.23e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 329         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 504          |
# |    ep_rew_mean          | 14.9         |
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 17           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0038140828 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 280          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 542          |
# |    ep_rew_mean          | 28.5         |
# | time/                   |              |
# |    fps                  | 1145         |
# |    iterations           | 18           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0044998894 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58           |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 269          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 575          |
# |    ep_rew_mean          | 37.5         |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 19           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0065604514 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.6         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000689    |
# |    value_loss           | 147          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 659          |
# |    ep_rew_mean          | 42.5         |
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 20           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0060619283 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.9         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.000901    |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 52.4        |
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 21          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.006161141 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 205         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 760          |
# |    ep_rew_mean          | 58.7         |
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 22           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0044006244 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 170          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 108          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 59.4         |
# | time/                   |              |
# |    fps                  | 1012         |
# |    iterations           | 23           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0051468275 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.1         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00075     |
# |    value_loss           | 112          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | 62.8         |
# | time/                   |              |
# |    fps                  | 997          |
# |    iterations           | 24           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0058239712 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35           |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000745    |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 763          |
# |    ep_rew_mean          | 70.4         |
# | time/                   |              |
# |    fps                  | 983          |
# |    iterations           | 25           |
# |    time_elapsed         | 416          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0052850926 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 88.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 763         |
# |    ep_rew_mean          | 76.1        |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 26          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.004673505 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 785         |
# |    ep_rew_mean          | 82.9        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 27          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.007797165 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.4        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.000772   |
# |    value_loss           | 86.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 816         |
# |    ep_rew_mean          | 88.8        |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 28          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.005822423 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.71        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.000451   |
# |    value_loss           | 41.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 840          |
# |    ep_rew_mean          | 98.1         |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 29           |
# |    time_elapsed         | 504          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0059070685 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10           |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 30.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 30           |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0063804397 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 36.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 31          |
# |    time_elapsed         | 550         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.006781799 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.000476    |
# |    value_loss           | 52.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 32           |
# |    time_elapsed         | 572          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0064586485 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 40.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 908          |
# |    iterations           | 33           |
# |    time_elapsed         | 594          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0048464546 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | 0.000136     |
# |    value_loss           | 9.25         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 34          |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.005891041 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89          |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.000737   |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 934         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 896         |
# |    iterations           | 35          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.007188644 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.96        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 8.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 892          |
# |    iterations           | 36           |
# |    time_elapsed         | 661          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0051113367 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.57         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000877    |
# |    value_loss           | 9.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 37          |
# |    time_elapsed         | 681         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.003931718 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 0.000239    |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 951         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 885         |
# |    iterations           | 38          |
# |    time_elapsed         | 703         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.005477445 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.7        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | 0.000319    |
# |    value_loss           | 21.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 951          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 39           |
# |    time_elapsed         | 723          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0043412503 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.93         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 4.29e-05     |
# |    value_loss           | 39.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 926        |
# |    ep_rew_mean          | 143        |
# | time/                   |            |
# |    fps                  | 881        |
# |    iterations           | 40         |
# |    time_elapsed         | 743        |
# |    total_timesteps      | 655360     |
# | train/                  |            |
# |    approx_kl            | 0.00520855 |
# |    clip_fraction        | 0.0519     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.835     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.501      |
# |    n_updates            | 156        |
# |    policy_gradient_loss | -0.000434  |
# |    value_loss           | 3.67       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 41           |
# |    time_elapsed         | 762          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0043779076 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.9         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00012      |
# |    value_loss           | 69.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 42           |
# |    time_elapsed         | 782          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0038945912 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3          |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.000416    |
# |    value_loss           | 27.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 43           |
# |    time_elapsed         | 800          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0040598377 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.801       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.5          |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000131    |
# |    value_loss           | 70.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 843          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 44           |
# |    time_elapsed         | 817          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0040797126 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.5         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 825          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 45           |
# |    time_elapsed         | 837          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0045584077 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000576    |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 46           |
# |    time_elapsed         | 854          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0034787464 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 221          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000225    |
# |    value_loss           | 190          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 732         |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 883         |
# |    iterations           | 47          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.004018398 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 183         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 609          |
# |    ep_rew_mean          | 207          |
# | time/                   |              |
# |    fps                  | 886          |
# |    iterations           | 48           |
# |    time_elapsed         | 886          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0055057323 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 356          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 341          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 462         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 49          |
# |    time_elapsed         | 901         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.008507218 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 156         |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 376         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 50          |
# |    time_elapsed         | 914         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.008212023 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 277         |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 357         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 239         |
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 51          |
# |    time_elapsed         | 927         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.005260822 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.744      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 405         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 905          |
# |    iterations           | 52           |
# |    time_elapsed         | 940          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0049870033 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.762       |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 221          |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000417    |
# |    value_loss           | 329          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 910          |
# |    iterations           | 53           |
# |    time_elapsed         | 953          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0046388693 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 186          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 493          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 292         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 54          |
# |    time_elapsed         | 966         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.004689551 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.744      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | 0.000625    |
# |    value_loss           | 111         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 285          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 55           |
# |    time_elapsed         | 979          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 75          |
# |    time_elapsed         | 1229        |
# |    total_timesteps      | 1228800     |
# | train/                  |             |
# |    approx_kl            | 0.004915992 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 296         |
# |    policy_gradient_loss | 0.000105    |
# |    value_loss           | 160         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 1003         |
# |    iterations           | 76           |
# |    time_elapsed         | 1241         |
# |    total_timesteps      | 1245184      |
# | train/                  |              |
# |    approx_kl            | 0.0049446034 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000577    |
# |    value_loss           | 7.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 77           |
# |    time_elapsed         | 1253         |
# |    total_timesteps      | 1261568      |
# | train/                  |              |
# |    approx_kl            | 0.0040486287 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.701       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.3         |
# |    n_updates            | 304          |
# |    policy_gradient_loss | 0.000272     |
# |    value_loss           | 176          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 78          |
# |    time_elapsed         | 1266        |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.005676559 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.24        |
# |    n_updates            | 308         |
# |    policy_gradient_loss | -0.000226   |
# |    value_loss           | 207         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 1012        |
# |    iterations           | 79          |
# |    time_elapsed         | 1278        |
# |    total_timesteps      | 1294336     |
# | train/                  |             |
# |    approx_kl            | 0.004680172 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 312         |
# |    policy_gradient_loss | 0.000669    |
# |    value_loss           | 397         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 254          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 1015         |
# |    iterations           | 80           |
# |    time_elapsed         | 1290         |
# |    total_timesteps      | 1310720      |
# | train/                  |              |
# |    approx_kl            | 0.0052721957 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.9         |
# |    n_updates            | 316          |
# |    policy_gradient_loss | 0.000846     |
# |    value_loss           | 277          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 1018        |
# |    iterations           | 81          |
# |    time_elapsed         | 1302        |
# |    total_timesteps      | 1327104     |
# | train/                  |             |
# |    approx_kl            | 0.003700777 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.46        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000957    |
# |    value_loss           | 262         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 82          |
# |    time_elapsed         | 1315        |
# |    total_timesteps      | 1343488     |
# | train/                  |             |
# |    approx_kl            | 0.005240692 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 324         |
# |    policy_gradient_loss | 5.85e-05    |
# |    value_loss           | 223         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 266          |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 1024         |
# |    iterations           | 83           |
# |    time_elapsed         | 1327         |
# |    total_timesteps      | 1359872      |
# | train/                  |              |
# |    approx_kl            | 0.0043808776 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.53         |
# |    n_updates            | 328          |
# |    policy_gradient_loss | 0.000848     |
# |    value_loss           | 18.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 1028        |
# |    iterations           | 84          |
# |    time_elapsed         | 1338        |
# |    total_timesteps      | 1376256     |
# | train/                  |             |
# |    approx_kl            | 0.005008956 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 182         |
# |    n_updates            | 332         |
# |    policy_gradient_loss | 0.000787    |
# |    value_loss           | 91.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 252        |
# |    ep_rew_mean          | 280        |
# | time/                   |            |
# |    fps                  | 1031       |
# |    iterations           | 85         |
# |    time_elapsed         | 1350       |
# |    total_timesteps      | 1392640    |
# | train/                  |            |
# |    approx_kl            | 0.00611264 |
# |    clip_fraction        | 0.0553     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.711     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.51       |
# |    n_updates            | 336        |
# |    policy_gradient_loss | -0.000916  |
# |    value_loss           | 4.86       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 253          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 1034         |
# |    iterations           | 86           |
# |    time_elapsed         | 1362         |
# |    total_timesteps      | 1409024      |
# | train/                  |              |
# |    approx_kl            | 0.0034602738 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.944        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000216     |
# |    value_loss           | 4.05         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 257          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 1036         |
# |    iterations           | 87           |
# |    time_elapsed         | 1374         |
# |    total_timesteps      | 1425408      |
# | train/                  |              |
# |    approx_kl            | 0.0051117283 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 344          |
# |    policy_gradient_loss | 0.000396     |
# |    value_loss           | 30           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 261         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 1039        |
# |    iterations           | 88          |
# |    time_elapsed         | 1386        |
# |    total_timesteps      | 1441792     |
# | train/                  |             |
# |    approx_kl            | 0.004410851 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94        |
# |    n_updates            | 348         |
# |    policy_gradient_loss | 0.000343    |
# |    value_loss           | 12.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 1042         |
# |    iterations           | 89           |
# |    time_elapsed         | 1399         |
# |    total_timesteps      | 1458176      |
# | train/                  |              |
# |    approx_kl            | 0.0053788507 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.09         |
# |    n_updates            | 352          |
# |    policy_gradient_loss | -0.000485    |
# |    value_loss           | 5.78         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 90           |
# |    time_elapsed         | 1411         |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0050196946 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 356          |
# |    policy_gradient_loss | 0.000474     |
# |    value_loss           | 23.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 91          |
# |    time_elapsed         | 1423        |
# |    total_timesteps      | 1490944     |
# | train/                  |             |
# |    approx_kl            | 0.004553047 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 642         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00029    |
# |    value_loss           | 213         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 242         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 92          |
# |    time_elapsed         | 1434        |
# |    total_timesteps      | 1507328     |
# | train/                  |             |
# |    approx_kl            | 0.005861314 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 364         |
# |    policy_gradient_loss | -5.08e-05   |
# |    value_loss           | 37.2        |
# -----------------------------------------

# %% [markdown]
# ## Evaluate the agent 📈
# - Now that our Lunar Lander agent is trained 🚀, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`.
# - To fill that part you need to [check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)
#
#
# 💡 When you evaluate your agent, you should not use your training environment but create an evaluation environment.

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=273.46 +/- 18.11657668450089

# %% [markdown]
# ## Publish the trained model on the Hugging Face Hub

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# Let's fill the `package_to_hub` function:
# - `model`: our trained model.
# - `model_name`: the name of the trained model that we defined in `model_save`
# - `model_architecture`: the model architecture we used: in our case PPO
# - `env_id`: the name of the environment, in our case `LunarLander-v2`
# - `eval_env`: the evaluation environment defined in eval_env
# - `repo_id`: the name of the Hugging Face Hub Repository that will be created/updated `(repo_id = {username}/{repo_name})`
#
# 💡 **A good name is {username}/{model_architecture}-{env_id}**
#
# - `commit_message`: message of the commit

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

## TODO: Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id = "gokcenazakyol/ppo-LunarLander-v2"

# TODO: Define the name of the environment
env_id = "LunarLander-v2"

# Create the evaluation env
eval_env = DummyVecEnv([lambda: gym.make(env_id)])


# TODO: Define the model architecture we used
model_architecture = "PPO"

## TODO: Define the commit message
commit_message = "Push LunarLander-v2 model"

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model 
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)

# Note: if after running the package_to_hub function and it gives an issue of rebasing, please run the following code
# cd <path_to_repo> && git add . && git commit -m "Add message" && git pull 
# And don't forget to do a "git push" at the end to push the change to the hub.
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmpuftdq4d8/-step-0-to-step-1000.mp4
# ℹ Pushing repo gokcenazakyol/ppo-LunarLander-v2 to the Hugging Face
# Hub
# pytorch_variables.pth:   0%|          | 0.00/431 [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/87.5k [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/43.3k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# ppo-LunarLander-v2.zip:   0%|          | 0.00/147k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/gokcenazakyol/ppo-LunarLander-v2/tree/main/
# 'https://huggingface.co/gokcenazakyol/ppo-LunarLander-v2/tree/main/'

# %% [markdown]
# ⬇️ Here is an example of what **I achieved** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/gokcenazakyol/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/gokcenazakyol/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
